# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
allegations = pd.read_excel("complaints-merged-2015/all complaints with geocoordinates lat lon (1).xlsx", sheetname="Allegations")
police_witnesses = pd.read_excel("complaints-merged-2015/all complaints with geocoordinates lat lon (1).xlsx", sheetname="Police Witnesses")
complaining_witnesses = pd.read_excel("complaints-merged-2015/all complaints with geocoordinates lat lon (1).xlsx", sheetname="Complaining Witnesses")
officer_profile = pd.read_excel("complaints-merged-2015/all complaints with geocoordinates lat lon (1).xlsx", sheetname="Officer Profile")

# %%
allegations.head()
# print(allegations.Allegation.value_counts())
test = allegations.Allegation.value_counts()[0:10]
test.plot(kind="bar", title="Top Allegations", figsize=(20,10))

# %%
top_findings = allegations.Finding.value_counts()
top_findings.plot(kind="bar")

# %%
allegations.OfficerID.head()
# top_officer = allegations[allegations["OfficerID"] == 2235.0]
# top_officer.Allegation.value_counts()
# Out:
# 0    3118.0
# 1    5668.0
# 2    3938.0
# 3    6850.0
# 4     547.0
# Name: OfficerID, dtype: float64

# %%
police_witnesses.head()
police_witnesses.Race.value_counts()
# Out:
# White                      1644
# Black                       799
# Hispanic                    645
# WHITE                       109
# Asian                        66
# BLACK                        49
# SPANISH (DO NOT USE)         34
# Native American              12
# ASIAN/PACIFIC ISLANDER        5
# WHITE HISPANIC                5
# AMER IND/ALASKAN NATIVE       2
# UNKNOWN                       2
# Unknown                       1
# Name: Race, dtype: int64

# %%
complaining_witnesses.head()
complaining_witnesses.Age.value_counts()
# Out:
# 45.0      508
# 36.0      425
# 32.0      416
# 46.0      414
# 31.0      410
# 43.0      407
# 51.0      406
# 35.0      404
# 37.0      400
# 39.0      398
# 34.0      390
# 29.0      389
# 27.0      388
# 28.0      388
# 33.0      381
# 38.0      381
# 42.0      377
# 44.0      377
# 49.0      375
# 47.0      370
# 30.0      364
# 25.0      355
# 54.0      354
# 48.0      344
# 26.0      342
# 52.0      341
# 40.0      338
# 53.0      329
# 55.0      324
# 50.0      316
#          ...
# 946.0       2
# 91.0        2
# 90.0        2
# 98.0        2
# 107.0       2
# 943.0       2
# 145.0       2
# 947.0       2
# 939.0       1
# 940.0       1
# 959.0       1
# 933.0       1
# 950.0       1
# 952.0       1
# 957.0       1
# 17.0        1
# 935.0       1
# 167.0       1
# 929.0       1
# 920.0       1
# 825.0       1
# 164.0       1
# 149.0       1
# 143.0       1
# 142.0       1
# 115.0       1
# 105.0       1
# 94.0        1
# 92.0        1
# 1820.0      1
# ...

# %%
officer_profile.head()
officer_profile[officer_profile["OfficerID"]==2235]
# Out:
#       OfficerID OfficerFirst OfficerLast Gender Race  ApptDate   Unit Rank  \
# 2233       2235       Jerome    Finnigan    NaN  NaN       NaN  153.0  NaN
#
#       Star  Age
# 2233   NaN  NaN
